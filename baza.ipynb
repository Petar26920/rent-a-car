-- %% [markdown]
-- # [FK_Vozilo_VozniPark]

-- %%
USE [ProjekatZaPPPKojiRadi]
GO

-- %%
ALTER TABLE [dbo].[Vozilo] DROP CONSTRAINT [FK_Vozilo_VozniPark]
GO

-- %% [markdown]
-- # [FK_Racun_Vozilo]

-- %%
ALTER TABLE [dbo].[Racun] DROP CONSTRAINT [FK_Racun_Vozilo]
GO

-- %% [markdown]
-- # [FK_Racun_Dokumentacija]

-- %%
ALTER TABLE [dbo].[Racun] DROP CONSTRAINT [FK_Racun_Dokumentacija]
GO

-- %% [markdown]
-- # [dbo].[VozniPark]

-- %%
/****** Object:  Table [dbo].[VozniPark]    Script Date: 1/31/2023 1:53:12 PM ******/
IF  EXISTS (SELECT * FROM sys.objects WHERE object_id = OBJECT_ID(N'[dbo].[VozniPark]') AND type in (N'U'))
DROP TABLE [dbo].[VozniPark]
GO

-- %% [markdown]
-- # [dbo].[Vozilo]

-- %%
/****** Object:  Table [dbo].[Vozilo]    Script Date: 1/31/2023 1:53:12 PM ******/
IF  EXISTS (SELECT * FROM sys.objects WHERE object_id = OBJECT_ID(N'[dbo].[Vozilo]') AND type in (N'U'))
DROP TABLE [dbo].[Vozilo]
GO

-- %% [markdown]
-- # [dbo].[Racun]

-- %%
/****** Object:  Table [dbo].[Racun]    Script Date: 1/31/2023 1:53:12 PM ******/
IF  EXISTS (SELECT * FROM sys.objects WHERE object_id = OBJECT_ID(N'[dbo].[Racun]') AND type in (N'U'))
DROP TABLE [dbo].[Racun]
GO

-- %% [markdown]
-- # [dbo].[Korisnici]

-- %%
/****** Object:  Table [dbo].[Korisnici]    Script Date: 1/31/2023 1:53:12 PM ******/
IF  EXISTS (SELECT * FROM sys.objects WHERE object_id = OBJECT_ID(N'[dbo].[Korisnici]') AND type in (N'U'))
DROP TABLE [dbo].[Korisnici]
GO

-- %% [markdown]
-- # [dbo].[Dokumentacija]

-- %%
/****** Object:  Table [dbo].[Dokumentacija]    Script Date: 1/31/2023 1:53:12 PM ******/
IF  EXISTS (SELECT * FROM sys.objects WHERE object_id = OBJECT_ID(N'[dbo].[Dokumentacija]') AND type in (N'U'))
DROP TABLE [dbo].[Dokumentacija]
GO

-- %% [markdown]
-- # [ProjekatZaPPPKojiRadi]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [ProjekatZaPPPKojiRadi]    Script Date: 1/31/2023 1:53:12 PM ******/
DROP DATABASE [ProjekatZaPPPKojiRadi]
GO

-- %%
/****** Object:  Database [ProjekatZaPPPKojiRadi]    Script Date: 1/31/2023 1:53:12 PM ******/
CREATE DATABASE [ProjekatZaPPPKojiRadi]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'SadStvarno', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.MSSQLSERVER01\MSSQL\DATA\SadStvarno.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'SadStvarno_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.MSSQLSERVER01\MSSQL\DATA\SadStvarno_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT
GO
ALTER DATABASE [ProjekatZaPPPKojiRadi] SET COMPATIBILITY_LEVEL = 150
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [ProjekatZaPPPKojiRadi].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [ProjekatZaPPPKojiRadi] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [ProjekatZaPPPKojiRadi] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [ProjekatZaPPPKojiRadi] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [ProjekatZaPPPKojiRadi] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [ProjekatZaPPPKojiRadi] SET ARITHABORT OFF 
GO
ALTER DATABASE [ProjekatZaPPPKojiRadi] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [ProjekatZaPPPKojiRadi] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [ProjekatZaPPPKojiRadi] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [ProjekatZaPPPKojiRadi] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [ProjekatZaPPPKojiRadi] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [ProjekatZaPPPKojiRadi] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [ProjekatZaPPPKojiRadi] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [ProjekatZaPPPKojiRadi] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [ProjekatZaPPPKojiRadi] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [ProjekatZaPPPKojiRadi] SET  DISABLE_BROKER 
GO
ALTER DATABASE [ProjekatZaPPPKojiRadi] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [ProjekatZaPPPKojiRadi] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [ProjekatZaPPPKojiRadi] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [ProjekatZaPPPKojiRadi] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [ProjekatZaPPPKojiRadi] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [ProjekatZaPPPKojiRadi] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [ProjekatZaPPPKojiRadi] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [ProjekatZaPPPKojiRadi] SET RECOVERY FULL 
GO
ALTER DATABASE [ProjekatZaPPPKojiRadi] SET  MULTI_USER 
GO
ALTER DATABASE [ProjekatZaPPPKojiRadi] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [ProjekatZaPPPKojiRadi] SET DB_CHAINING OFF 
GO
ALTER DATABASE [ProjekatZaPPPKojiRadi] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [ProjekatZaPPPKojiRadi] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [ProjekatZaPPPKojiRadi] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [ProjekatZaPPPKojiRadi] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'ProjekatZaPPPKojiRadi', N'ON'
GO
ALTER DATABASE [ProjekatZaPPPKojiRadi] SET QUERY_STORE = OFF
GO

-- %% [markdown]
-- # [dbo].[Dokumentacija]

-- %%
USE [ProjekatZaPPPKojiRadi]
GO

-- %%
/****** Object:  Table [dbo].[Dokumentacija]    Script Date: 1/31/2023 1:53:12 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Dokumentacija](
	[IDVozacke] [int] NOT NULL,
	[Ime] [varchar](50) NOT NULL,
	[Prezime] [varchar](50) NOT NULL,
	[DatumRodjenja] [date] NOT NULL,
	[DatumIzdavanjaDozvole] [date] NOT NULL,
 CONSTRAINT [PK_Dokumentacija] PRIMARY KEY CLUSTERED 
(
	[IDVozacke] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Korisnici]

-- %%
/****** Object:  Table [dbo].[Korisnici]    Script Date: 1/31/2023 1:53:12 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Korisnici](
	[KorisnickoIme] [nvarchar](50) NOT NULL,
	[Sifra] [nvarchar](50) NOT NULL,
	[Uloga] [varchar](50) NOT NULL,
 CONSTRAINT [PK_Korisnici] PRIMARY KEY CLUSTERED 
(
	[KorisnickoIme] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Racun]

-- %%
/****** Object:  Table [dbo].[Racun]    Script Date: 1/31/2023 1:53:12 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Racun](
	[Racun_ID] [int] NOT NULL,
	[Vozilo_FK] [varchar](50) NOT NULL,
	[Dokumentacija_FK] [int] NOT NULL,
	[Cena] [money] NOT NULL,
	[BrojDana] [int] NOT NULL,
	[Datum] [date] NOT NULL,
 CONSTRAINT [PK_Racun_1] PRIMARY KEY CLUSTERED 
(
	[Racun_ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Vozilo]

-- %%
/****** Object:  Table [dbo].[Vozilo]    Script Date: 1/31/2023 1:53:12 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Vozilo](
	[RegistracioniBroj] [varchar](50) NOT NULL,
	[VozniPark_FK] [int] NOT NULL,
	[Boja] [varchar](50) NOT NULL,
	[Tezina] [float] NOT NULL,
	[Tip] [varchar](50) NOT NULL,
	[Model] [varchar](50) NOT NULL,
	[Zauzeto] [bit] NOT NULL,
 CONSTRAINT [PK_Vozilo] PRIMARY KEY CLUSTERED 
(
	[RegistracioniBroj] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[VozniPark]

-- %%
/****** Object:  Table [dbo].[VozniPark]    Script Date: 1/31/2023 1:53:12 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[VozniPark](
	[VozniPark_ID] [int] NOT NULL,
	[Naziv] [varchar](50) NOT NULL,
 CONSTRAINT [PK_VozniPark] PRIMARY KEY CLUSTERED 
(
	[VozniPark_ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Dokumentacija]

-- %%
INSERT [dbo].[Dokumentacija] ([IDVozacke], [Ime], [Prezime], [DatumRodjenja], [DatumIzdavanjaDozvole]) VALUES (1, N'Sladjan', N'Mihajlovic', CAST(N'2001-04-05' AS Date), CAST(N'2020-05-05' AS Date))
INSERT [dbo].[Dokumentacija] ([IDVozacke], [Ime], [Prezime], [DatumRodjenja], [DatumIzdavanjaDozvole]) VALUES (2, N'Petar', N'NEdeljkovic', CAST(N'2001-10-08' AS Date), CAST(N'2020-05-05' AS Date))
INSERT [dbo].[Dokumentacija] ([IDVozacke], [Ime], [Prezime], [DatumRodjenja], [DatumIzdavanjaDozvole]) VALUES (3, N'Mina', N'Rakic', CAST(N'2001-10-13' AS Date), CAST(N'2019-04-04' AS Date))
GO

-- %% [markdown]
-- # [dbo].[Korisnici]

-- %%
INSERT [dbo].[Korisnici] ([KorisnickoIme], [Sifra], [Uloga]) VALUES (N'admin', N'admin123', N'admin')
INSERT [dbo].[Korisnici] ([KorisnickoIme], [Sifra], [Uloga]) VALUES (N'korisnik', N'korisnik123', N'korisnik')
GO

-- %% [markdown]
-- # [dbo].[Racun]

-- %%
INSERT [dbo].[Racun] ([Racun_ID], [Vozilo_FK], [Dokumentacija_FK], [Cena], [BrojDana], [Datum]) VALUES (1, N'123', 1, 500.0000, 2, CAST(N'2020-10-10' AS Date))
INSERT [dbo].[Racun] ([Racun_ID], [Vozilo_FK], [Dokumentacija_FK], [Cena], [BrojDana], [Datum]) VALUES (2, N'123', 1, 600.0000, 3, CAST(N'2020-11-11' AS Date))
INSERT [dbo].[Racun] ([Racun_ID], [Vozilo_FK], [Dokumentacija_FK], [Cena], [BrojDana], [Datum]) VALUES (3, N'456', 2, 700.0000, 4, CAST(N'2020-04-05' AS Date))
INSERT [dbo].[Racun] ([Racun_ID], [Vozilo_FK], [Dokumentacija_FK], [Cena], [BrojDana], [Datum]) VALUES (5, N'789', 3, 800.0000, 3, CAST(N'2020-10-11' AS Date))
INSERT [dbo].[Racun] ([Racun_ID], [Vozilo_FK], [Dokumentacija_FK], [Cena], [BrojDana], [Datum]) VALUES (6, N'159', 1, 900.0000, 2, CAST(N'2021-10-10' AS Date))
INSERT [dbo].[Racun] ([Racun_ID], [Vozilo_FK], [Dokumentacija_FK], [Cena], [BrojDana], [Datum]) VALUES (7, N'456', 2, 1000.0000, 2, CAST(N'2022-01-01' AS Date))
INSERT [dbo].[Racun] ([Racun_ID], [Vozilo_FK], [Dokumentacija_FK], [Cena], [BrojDana], [Datum]) VALUES (8, N'123', 2, 1200.0000, 3, CAST(N'2021-01-01' AS Date))
GO

-- %% [markdown]
-- # [dbo].[Vozilo]

-- %%
INSERT [dbo].[Vozilo] ([RegistracioniBroj], [VozniPark_FK], [Boja], [Tezina], [Tip], [Model], [Zauzeto]) VALUES (N'123', 1, N'zuta', 1500, N'karavan', N's', 0)
INSERT [dbo].[Vozilo] ([RegistracioniBroj], [VozniPark_FK], [Boja], [Tezina], [Tip], [Model], [Zauzeto]) VALUES (N'159', 1, N'crvena', 3000, N'dzip', N'k', 0)
INSERT [dbo].[Vozilo] ([RegistracioniBroj], [VozniPark_FK], [Boja], [Tezina], [Tip], [Model], [Zauzeto]) VALUES (N'456', 2, N'braon', 2000, N'skuter', N'l', 0)
INSERT [dbo].[Vozilo] ([RegistracioniBroj], [VozniPark_FK], [Boja], [Tezina], [Tip], [Model], [Zauzeto]) VALUES (N'753', 2, N'roze', 1000, N'limuzina', N'b', 0)
INSERT [dbo].[Vozilo] ([RegistracioniBroj], [VozniPark_FK], [Boja], [Tezina], [Tip], [Model], [Zauzeto]) VALUES (N'789', 1, N'plava', 2500, N'dzip', N'd', 0)
GO

-- %% [markdown]
-- # [dbo].[VozniPark]

-- %%
INSERT [dbo].[VozniPark] ([VozniPark_ID], [Naziv]) VALUES (1, N'Beogradski')
INSERT [dbo].[VozniPark] ([VozniPark_ID], [Naziv]) VALUES (2, N'Pozarevacki')
GO

-- %% [markdown]
-- # [FK_Racun_Dokumentacija]

-- %%
ALTER TABLE [dbo].[Racun]  WITH CHECK ADD  CONSTRAINT [FK_Racun_Dokumentacija] FOREIGN KEY([Dokumentacija_FK])
REFERENCES [dbo].[Dokumentacija] ([IDVozacke])
GO
ALTER TABLE [dbo].[Racun] CHECK CONSTRAINT [FK_Racun_Dokumentacija]
GO

-- %% [markdown]
-- # [FK_Racun_Vozilo]

-- %%
ALTER TABLE [dbo].[Racun]  WITH CHECK ADD  CONSTRAINT [FK_Racun_Vozilo] FOREIGN KEY([Vozilo_FK])
REFERENCES [dbo].[Vozilo] ([RegistracioniBroj])
GO
ALTER TABLE [dbo].[Racun] CHECK CONSTRAINT [FK_Racun_Vozilo]
GO

-- %% [markdown]
-- # [FK_Vozilo_VozniPark]

-- %%
ALTER TABLE [dbo].[Vozilo]  WITH CHECK ADD  CONSTRAINT [FK_Vozilo_VozniPark] FOREIGN KEY([VozniPark_FK])
REFERENCES [dbo].[VozniPark] ([VozniPark_ID])
GO
ALTER TABLE [dbo].[Vozilo] CHECK CONSTRAINT [FK_Vozilo_VozniPark]
GO

-- %% [markdown]
-- # [ProjekatZaPPPKojiRadi]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [ProjekatZaPPPKojiRadi] SET  READ_WRITE 
GO
